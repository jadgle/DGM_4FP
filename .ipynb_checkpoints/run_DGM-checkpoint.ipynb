# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import matplotlib
from dgm_library_ergodic import env_initializing, sample_room, init_DGM, train, warmstart

from DGM import * # NOQA
import numpy as np
import keras
import pandas as pd
from tensorflow.python.ops.numpy_ops import np_config

env_initializing()

DTYPE = 'float32

Phi_theta = init_DGM(RNN_layers = 1, FNN_layers=1, nodes_per_layer=6,activation="tanh")
Gamma_theta = init_DGM(RNN_layers = 1, FNN_layers=1, nodes_per_layer=6,activation="tanh")

# %%
verbose=1

phi = pd.read_csv('phi.txt', header = None)
gamma = pd.read_csv('gamma.txt', header = None)

Phi_theta,Gamma_theta, X0  = warmstart_sol(Phi_theta,Gamma_theta,phi,gamma,2)
# Out:
# ------ preprocessing for Gamma_theta ------
# Gamma_theta It 00000: loss = 2.65581036e+01
# Gamma_theta It 00050: loss = 8.53689480e+00
# Gamma_theta It 00100: loss = 2.93032646e+00
# Gamma_theta It 00150: loss = 1.80116928e+00
# Gamma_theta It 00200: loss = 1.21260464e+00
# Gamma_theta It 00250: loss = 8.50026131e-01
# Gamma_theta It 00300: loss = 6.25263095e-01
# Gamma_theta It 00350: loss = 4.53550577e-01
# Gamma_theta It 00400: loss = 3.31946522e-01
# Gamma_theta It 00450: loss = 2.53145903e-01
# Gamma_theta It 00500: loss = 2.02563584e-01
# Gamma_theta It 00550: loss = 1.67231098e-01
# Gamma_theta It 00600: loss = 1.41568810e-01
# Gamma_theta It 00650: loss = 1.22898370e-01
# Gamma_theta It 00700: loss = 1.07879773e-01
# Gamma_theta It 00750: loss = 9.66376364e-02
# Gamma_theta It 00800: loss = 8.76796022e-02
# Gamma_theta It 00850: loss = 8.11607167e-02
# Gamma_theta It 00900: loss = 7.77420551e-02
# Gamma_theta It 00950: loss = 7.50191361e-02
# Gamma_theta It 01000: loss = 6.76741824e-02
# Gamma_theta It 01050: loss = 6.28542751e-02
# Gamma_theta It 01100: loss = 5.98396659e-02
# Gamma_theta It 01150: loss = 5.69481254e-02
# Gamma_theta It 01200: loss = 5.44514880e-02
# Gamma_theta It 01250: loss = 5.22272959e-02
# Gamma_theta It 01300: loss = 5.02349921e-02
# Gamma_theta It 01350: loss = 4.84316945e-02
# Gamma_theta It 01400: loss = 4.67893519e-02
# Gamma_theta It 01450: loss = 4.52884100e-02
# Gamma_theta It 01500: loss = 4.39175293e-02
# Gamma_theta It 01550: loss = 4.26296294e-02
# Gamma_theta It 01600: loss = 4.14204411e-02
# Gamma_theta It 01650: loss = 4.02739644e-02
# Gamma_theta It 01700: loss = 3.92026342e-02
# Gamma_theta It 01750: loss = 3.81852612e-02
# Gamma_theta It 01800: loss = 3.72085571e-02
# Gamma_theta It 01850: loss = 3.62889767e-02
# Gamma_theta It 01900: loss = 3.54097448e-02
# Gamma_theta It 01950: loss = 3.45616192e-02
# Gamma_theta It 02000: loss = 3.37609239e-02
# ------ preprocessing  for Phi_theta------
# Phi_theta It 00000: loss = 1.15895317e+02
# Phi_theta It 00050: loss = 7.57298203e+01
# Phi_theta It 00100: loss = 3.07167053e+01
# Phi_theta It 00150: loss = 9.02709293e+00
# Phi_theta It 00200: loss = 4.11342192e+00
# Phi_theta It 00250: loss = 2.28295541e+00
# Phi_theta It 00300: loss = 1.48511291e+00
# Phi_theta It 00350: loss = 1.05367148e+00
# Phi_theta It 00400: loss = 7.87475705e-01
# Phi_theta It 00450: loss = 6.22972965e-01
# Phi_theta It 00500: loss = 5.08628011e-01
# Phi_theta It 00550: loss = 4.23504978e-01
# Phi_theta It 00600: loss = 3.58930528e-01
# Phi_theta It 00650: loss = 3.09123486e-01
# Phi_theta It 00700: loss = 2.69834846e-01
# Phi_theta It 00750: loss = 2.36922115e-01
# Phi_theta It 00800: loss = 2.09533006e-01
# Phi_theta It 00850: loss = 1.86150178e-01
# Phi_theta It 00900: loss = 1.66474998e-01
# Phi_theta It 00950: loss = 1.48843676e-01
# Phi_theta It 01000: loss = 1.33737624e-01
# Phi_theta It 01050: loss = 1.20142944e-01
# Phi_theta It 01100: loss = 1.11319438e-01
# Phi_theta It 01150: loss = 1.01618305e-01
# Phi_theta It 01200: loss = 9.15257931e-02
# Phi_theta It 01250: loss = 8.56900364e-02
# Phi_theta It 01300: loss = 7.91102052e-02
# Phi_theta It 01350: loss = 7.44634271e-02
# Phi_theta It 01400: loss = 7.30202720e-02
# Phi_theta It 01450: loss = 6.87371194e-02
# Phi_theta It 01500: loss = 6.51742890e-02
# Phi_theta It 01550: loss = 6.21364713e-02
# Phi_theta It 01600: loss = 5.95184825e-02
# Phi_theta It 01650: loss = 5.70947640e-02
# Phi_theta It 01700: loss = 5.48837781e-02
# Phi_theta It 01750: loss = 5.28999530e-02
# Phi_theta It 01800: loss = 5.10667451e-02
# Phi_theta It 01850: loss = 4.93619367e-02
# Phi_theta It 01900: loss = 4.77482751e-02
# Phi_theta It 01950: loss = 4.62429076e-02
# Phi_theta It 02000: loss = 4.48129624e-02

# %%
x = X0.iloc[:,0]
y = X0.iloc[:,1]
m = Gamma_theta(X0)*Phi_theta(X0)

fig = plt.figure(figsize=(7,6))
plt.scatter(x, y, c=m, cmap='hot_r')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.clim([0,3])
plt.colorbar()
plt.show()


# usual = matplotlib.cm.hot_r(np.arange(256))
# saturate = np.ones((int(256 / 20), 4))
# for i in range(3):
#     saturate[:, i] = np.linspace(usual[-1, i], 0, saturate.shape[0])
# cmap1 = np.vstack((usual, saturate))
# cmap1 = matplotlib.colors.ListedColormap(cmap1, name='myColorMap', N=cmap1.shape[0])

# fig = plt.figure(figsize=(7,6))
# #plt.scatter(x, y, c=m, cmap=cmap1, marker='.', alpha=0.3)

# np_config.enable_numpy_behavior()
# x_ = x_.reshape(50,50)
# y_ = y_.reshape(50,50)
# Phi = Phi_theta(X0)
# Gamma = Gamma_theta(X0)
# m = Phi*Gamma
# m = m.reshape(50,50)
# plt.contourf(x_, y_, m, 100, cmap=cmap1)
# plt.xlabel('$x$')
# plt.ylabel('$y$')
# plt.colorbar()
# plt.show()
